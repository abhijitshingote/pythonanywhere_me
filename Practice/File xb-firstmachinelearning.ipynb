# %% [markdown]
# ##### http://machinelearningmastery.com/machine-learning-in-python-step-by-step/

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn import model_selection
# %matplotlib inline

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(url, names=names)

# %% [markdown]
# Dimensions of the dataset.
# Peek at the data itself.
# Statistical summary of all attributes.
# Breakdown of the data by the class variable.

# %%
dataset.shape # 150 rows and 5 columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-282d2bf4c3b4> in <module>()
# ----> 1 dataset.shape # 150 rows and 5 columns
#
# NameError: name 'dataset' is not defined

# %%
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataset.describe()
# Out:
#        sepal-length  sepal-width  petal-length  petal-width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
dataset.groupby('class').size()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %% [markdown]
# #### Visualization
# 1. Univariate Plots - boxplot, histogram
# 2. Multivariate Plots - scatterplot

# %%
dataset.plot(kind='box',subplots=True,layout=(2,2),figsize=(8,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a042da290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a041ebad0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a0416ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a040da590>]], dtype=object)

# %%
# dataset.plot(kind='hist',subplots=True,layout=(2,2),figsize=(8,6))
dataset.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6a04341890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffed1590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffe54410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6a044bf850>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(dataset)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffdb8f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffbbfc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffac2a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffaa5f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ffa28e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff990b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff91acd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff89eb50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff80d610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff78f590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff7754d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff6f6450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff6ae550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff5e82d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff56a150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f69ff4d0290>]], dtype=object)

# %% [markdown]
# # Algorithms

# %%
# Split-out validation dataset
array = dataset.values
X = array[:,0:4]
Y = array[:,4]
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
print(X_train.shape,X_validation.shape)
print(Y_train.shape,Y_validation.shape)
# Out:
# (120, 4) (30, 4)
# (120,) (30,)

# %%
X_train
# Out:
# array([[6.2, 2.8, 4.8, 1.8],
#        [5.7, 2.6, 3.5, 1.0],
#        [4.6, 3.6, 1.0, 0.2],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.4, 2.9, 4.3, 1.3],
#        [4.8, 3.0, 1.4, 0.3],
#        [5.5, 3.5, 1.3, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [7.1, 3.0, 5.9, 2.1],
#        [6.7, 3.3, 5.7, 2.1],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.5, 3.0, 5.5, 1.8],
#        [5.7, 3.0, 4.2, 1.2],
#        [5.0, 3.3, 1.4, 0.2],
#        [6.7, 3.1, 4.4, 1.4],
#        [6.0, 2.2, 4.0, 1.0],
#        [6.4, 2.7, 5.3, 1.9],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [7.7, 3.8, 6.7, 2.2],
#        [4.3, 3.0, 1.1, 0.1],
#        [6.3, 3.3, 6.0, 2.5],
#        [5.5, 2.4, 3.7, 1.0],
#        [5.0, 2.0, 3.5, 1.0],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.0, 3.4, 1.6, 0.4],
#        [4.4, 2.9, 1.4, 0.2],
#        [5.0, 3.5, 1.6, 0.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [7.3, 2.9, 6.3, 1.8],
#        [5.5, 2.6, 4.4, 1.2],
#        [5.2, 2.7, 3.9, 1.4],
#        [5.7, 4.4, 1.5, 0.4],
#        [7.2, 3.2, 6.0, 1.8],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.8, 4.0, 1.2, 0.2],
#        [6.1, 2.6, 5.6, 1.4],
#        [5.7, 2.5, 5.0, 2.0],
#        [4.8, 3.0, 1.4, 0.1],
#        [6.5, 3.0, 5.8, 2.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [6.6, 2.9, 4.6, 1.3],
#        [6.7, 3.0, 5.2, 2.3],
#        [6.1, 3.0, 4.6, 1.4],
#        [5.7, 3.8, 1.7, 0.3],
#        [7.0, 3.2, 4.7, 1.4],
#        [4.7, 3.2, 1.3, 0.2],
#        [6.5, 3.0, 5.2, 2.0],
#        [7.7, 2.6, 6.9, 2.3],
#        [4.9, 2.4, 3.3, 1.0],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.5, 4.2, 1.4, 0.2],
#        [5.6, 3.0, 4.1, 1.3],
#        [6.4, 3.2, 5.3, 2.3],
#        [5.2, 3.5, 1.5, 0.2],
#        [7.9, 3.8, 6.4, 2.0],
#        [5.8, 2.8, 5.1, 2.4],
#        [5.7, 2.9, 4.2, 1.3],
#        [5.1, 3.7, 1.5, 0.4],
#        [5.1, 2.5, 3.0, 1.1],
#        [5.0, 3.4, 1.5, 0.2],
#        [7.7, 2.8, 6.7, 2.0],
#        [7.6, 3.0, 6.6, 2.1],
#        [5.0, 3.2, 1.2, 0.2],
#        [5.4, 3.7, 1.5, 0.2],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.1, 2.8, 4.0, 1.3],
#        [6.3, 2.5, 5.0, 1.9],
#        [7.4, 2.8, 6.1, 1.9],
#        [5.0, 2.3, 3.3, 1.0],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.6, 2.8, 4.9, 2.0],
#        [4.9, 3.0, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [6.0, 2.7, 5.1, 1.6],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 2.3, 4.4, 1.3],
#        [4.9, 3.1, 1.5, 0.1],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.0, 3.6, 1.4, 0.2],
#        [4.4, 3.0, 1.3, 0.2],
#        [6.0, 2.9, 4.5, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.8, 5.6, 2.1],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.6, 2.9, 3.6, 1.3],
#        [5.9, 3.0, 4.2, 1.5],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.8, 3.0, 5.5, 2.1],
#        [5.5, 2.3, 4.0, 1.3],
#        [6.3, 2.8, 5.1, 1.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [6.3, 3.3, 4.7, 1.6],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.1, 3.8, 1.9, 0.4],
#        [5.1, 3.8, 1.5, 0.3],
#        [4.6, 3.4, 1.4, 0.3],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.6, 3.0, 4.4, 1.4],
#        [5.1, 3.5, 1.4, 0.2],
#        [7.7, 3.0, 6.1, 2.3],
#        [6.1, 3.0, 4.9, 1.8],
#        [6.2, 2.2, 4.5, 1.5],
#        [6.3, 3.4, 5.6, 2.4],
#        [4.4, 3.2, 1.3, 0.2],
#        [6.5, 3.2, 5.1, 2.0],
#        [5.5, 2.5, 4.0, 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [5.1, 3.3, 1.7, 0.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [5.8, 2.6, 4.0, 1.2],
#        [6.3, 2.9, 5.6, 1.8],
#        [5.8, 2.7, 4.1, 1.0],
#        [5.0, 3.0, 1.6, 0.2]], dtype=object)
