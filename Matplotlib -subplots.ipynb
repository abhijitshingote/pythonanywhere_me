# %%
from glob import glob
pathname='stage1_train/'+'00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552'+'/masks/'+ '*'
imagepaths=glob(pathname)

# %%
imagepaths[0]
# Out:
# 'stage1_train/00071198d059ba7f5914a526d124d28e6d010c92466da21d4a04cd5413362552/masks/07a9bf1d7594af2763c86e93f05d22c4d5181353c6d3ab30a345b908ffe5aadc.png'

# %%
#load image 
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

figure=plt.figure(figsize=[24,100])
for index,imagepath in enumerate(imagepaths):
    plt.subplot(9,3,index+1) #x-axis - 9 rows, y-axis - 3columns, index 1
    image=mpimg.imread(imagepath)
    plt.imshow(image)
